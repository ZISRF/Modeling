# %%
# Values

Ms = 2e30
Rs = 6.957e8

Me = 5.972e24
Re = 6.371e6

R = 1.496e11

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

fig = plt.figure()
ax = fig.add_subplot()
ax.set(xlim=(-2*R, 2*R), ylim=(-2*R, 2*R))

plt.plot([0], [0], 'yo', markersize=28)
plt.plot([R], [0], 'o')

x = []
y = []
for angle in np.arange(0, 2*math.pi, 0.1):
    x.append(R * math.cos(angle))
    y.append(R * math.sin(angle))

plt.plot(x, y, linestyle='--', linewidth=0.5, color=(0, 0, 0), )
